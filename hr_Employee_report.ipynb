# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading dataset

# %%
hr_data = pd.read_csv('HR-Employee-Attrition.csv')

# %%
#previewing dataset
hr_data.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
#getting information on dataset
hr_data.info
# Out:
# <bound method DataFrame.info of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
hr_data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
hr_data.shape
# Out:
# (1470, 35)

# %%
#renaming column
hr_data.rename(columns={'EmployeeNumber': 'EmployeeId'}, inplace=True)

# %%
hr_data.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeId  ...  \
# 0                 1          2  Life Sciences              1           1  ...
# 1                 8          1  Life Sciences              1           2  ...
# 2                 2          2          Other              1           4  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# 1                         4            80                 1
# 2                         2            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
#dropping duplicates
hr_data.drop_duplicates(subset='EmployeeId', keep='first', inplace=True)

# %%
hr_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeId  ...  \
# 0                 1          2  Life Sciences              1           1  ...
# 1                 8          1  Life Sciences              1           2  ...
# 2                 2          2          Other              1           4  ...
# 3                 3          4  Life Sciences              1           5  ...
# 4                 2          1        Medical              1           7  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
hr_data.shape
# Out:
# (1470, 35)

# %%
# Dropping redundant columns (if any)
redundant_columns = ['EmployeeCount', 'StandardHours', 'Over18']
hr_data.drop(columns=redundant_columns, inplace=True)

# %%
# Cleaning individual columns (example: removing leading/trailing spaces from 'JobRole')
hr_data['JobRole'] = hr_data['JobRole'].str.strip()

# %%
# Removing NaN (missing) values
hr_data.dropna(inplace=True)

# %%
# Example: Binning 'Age' into age groups
bins = [18, 30, 40, 50, 60, float('inf')]
labels = ['18-29', '30-39', '40-49', '50-59', '60+']
hr_data['AgeGroup'] = pd.cut(hr_data['Age'], bins=bins, labels=labels)

# %%
# Additional Transformations (you can customize these based on your needs)
# Example: Creating a new column for total years of experience
hr_data['TotalExperience'] = hr_data['TotalWorkingYears'] - hr_data['NumCompaniesWorked']

# %%
hr_data.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeId  \
# 0                 1          2  Life Sciences           1
# 1                 8          1  Life Sciences           2
# 2                 2          2          Other           4
#
#    EnvironmentSatisfaction  ... StockOptionLevel  TotalWorkingYears  \
# 0                        2  ...                0                  8
# 1                        3  ...                1                 10
# 2                        4  ...                0                  7
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1              6                   4
# ...

# %%
# Plot a correlation map for all numeric variables
correlation_matrix = data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Map for Numeric Variables')
plt.show()
# Out:
# <ipython-input-51-7247a722f293>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# Create subplots for specific relationships
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

# %%
# Relation between Overtime and Age
sns.boxplot(x='OverTime', y='Age', data=hr_data, ax=axes[0, 0])
axes[0, 0].set_title('Relation between Overtime and Age')
# Out:
# Text(0.5, 1.0, 'Relation between Overtime and Age')

# %%
# Total Working Years vs. Education Level
sns.barplot(x='Education', y='TotalWorkingYears', data=hr_data, ax=axes[0, 1])
axes[0, 1].set_title('Total Working Years vs. Education Level')
# Out:
# Text(0.5, 1.0, 'Total Working Years vs. Education Level')

# %%
# Number of Companies Worked vs. Education Level
sns.barplot(x='Education', y='NumCompaniesWorked', data=hr_data, ax=axes[1, 0])
axes[1, 0].set_title('Number of Companies Worked vs. Education Level')
# Out:
# Text(0.5, 1.0, 'Number of Companies Worked vs. Education Level')

# %%
# Distance from Home vs. Education Level
sns.boxplot(x='Education', y='DistanceFromHome', data=hr_data, ax=axes[1, 1])
axes[1, 1].set_title('Distance from Home vs. Education Level')
# Out:
# Text(0.5, 1.0, 'Distance from Home vs. Education Level')

# %%
plt.tight_layout()
plt.show()

# %%
# Plot categorical variables (e.g., Overtime, Marital Status, Job Role, Gender, Education Field, Department, Business Travel)
categorical_variables = ['OverTime', 'MaritalStatus', 'JobRole', 'Gender', 'EducationField', 'Department', 'BusinessTravel']
for var in categorical_variables:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=var, data=hr_data, palette='Set2')
    plt.title(f'Count of Employees by {var}')
    plt.xticks(rotation=45)
    plt.show()
